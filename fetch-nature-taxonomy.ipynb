# %%
from bs4 import BeautifulSoup
import requests

from urllib.request import urlopen
import time
import json

# %%
nature_root = 'https://www.nature.com'
sleep_interval = 1 # seconds

# %%
def get_tax_node(subj_string):
    fetch_url = nature_root + '/subjects/' + subj_string
    html_content = requests.get(fetch_url).text
    soup = BeautifulSoup(html_content, "lxml")
    
    topic_id = subj_string
    name = soup.find_all('h1')[1].get_text()
    
    
    rel_subjs = [el for el in soup.find_all('h2') if 'Related Subjects' in el]

    if len(rel_subjs) == 0:
        children = []
    else:
        children_tags = rel_subjs[0].findNext('div').find_all('a')
        children = [child.get('href').replace('/subjects/','') for child in children_tags]

    return {'topic_id': topic_id,
            'name': name,
            'children': children}

# %%
def get_full_taxonomy_below(subj_string):
    queue = [subj_string]
    topic_list = []
    topic_ids = []

    while len(queue) > 0:
        
        # work in order
        current = queue.pop(0)
        
        if current in topic_ids:
            print('WARNING! {} is already in the list of fetched topics. Skipping.'.format(current))
            continue

        print('Fetching {}'.format(current))
        curr_node = get_tax_node(current)
        
        topic_list.append(curr_node)
        topic_ids.append(curr_node['topic_id'])
        
        queue.extend(curr_node['children'])

        # Slow ourselves down so the server doesn't get mad at us
        time.sleep(sleep_interval)
        print('queue length {}'.format(len(queue)))
        
    return topic_list

# %%
biology_tax = get_full_taxonomy_below('biological-sciences')
# Out:
# Fetching biological-sciences
# queue length 24
# Fetching biochemistry
# queue length 55
# Fetching biological-techniques
# queue length 86
# Fetching biophysics
# queue length 99
# Fetching biotechnology
# queue length 126
# Fetching cancer
# queue length 125
# Fetching cell-biology
# queue length 147
# Fetching chemical-biology
# queue length 191
# Fetching computational-biology-and-bioinformatics
# queue length 232
# Fetching developmental-biology
# queue length 260
# Fetching drug-discovery
# queue length 273
# Fetching ecology
# queue length 310
# Fetching evolution
# queue length 327
# Fetching genetics
# queue length 369
# Fetching immunology
# queue length 404
# Fetching microbiology
# queue length 426
# Fetching molecular-biology
# queue length 449
# Fetching neuroscience
# queue length 496
# Fetching physiology
# queue length 506
# Fetching plant-sciences
# queue length 528
# Fetching psychology
# queue length 528
# Fetching stem-cells
# queue length 551
# Fetching structural-biology
# queue length 556
# Fetching systems-biology
# queue length 600
# Fetching zoology
# queue length 605
# Fetching biocatalysis
# queue length 604
# Fetching biogeochemistry
# queue length 605
# Fetching bioinorganic-chemistry
# queue length 607
# Fetching biophysical-chemistry
# queue length 606
# Fetching carbohydrates
# queue length 614
# Fetching chemical-modification
# queue length 613
# Fetching cytokines
# queue length 625
# Fetching dna
# queue length 624
# Fetching enzyme-mechanisms
# queue length 623
# Fetching enzymes
# queue length 639
# Fetching glycobiology
# queue length 638
# Fetching glycomics
# queue length 637
# Fetching histocytochemistry
# queue length 637
# Fetching hormones
# queue length 649
# Fetching immunochemistry
# queue length 648
# Fetching ion-channels
# queue length 655
# Fetching isoenzymes
# queue length 654
# Fetching kinases
# queue length 653
# Fetching lipidomics
# queue length 652
# Fetching lipids
# queue length 669
# Fetching metabolomics
# queue length 668
# Fetching metals
# queue length 672
# Fetching neurochemistry
# queue length 671
# Fetching peptides
# queue length 670
# Fetching prions
# queue length 669
# Fetching proteases
# queue length 668
# Fetching protein-folding
# queue length 671
# Fetching proteins
# queue length 713
# Fetching proteolysis
# queue length 721
# Fetching proteomics
# queue length 721
# Fetching rna
# queue length 720
# WARNING! structural-biology is already in the list of fetched topics. Skipping.
# Fetching analytical-biochemistry
# queue length 723
# Fetching behavioural-methods
# queue length 723
# Fetching bioinformatics
# queue length 722
# Fetching biological-models
# queue length 732
# Fetching biophysical-methods
# queue length 735
# Fetching cytological-techniques
# queue length 743
# Fetching electrophysiology
# queue length 752
# Fetching epigenetics-analysis
# queue length 754
# Fetching experimental-organisms
# queue length 762
# Fetching gene-delivery
# queue length 765
# Fetching gene-expression-analysis
# queue length 771
# Fetching genetic-engineering
# queue length 770
# Fetching genetic-techniques
# queue length 773
# Fetching genomic-analysis
# queue length 780
# Fetching high-throughput-screening
# queue length 779
# Fetching imaging
# queue length 793
# Fetching immunological-techniques
# queue length 800
# Fetching isolation-separation-purification
# queue length 806
# Fetching lab-on-a-chip
# queue length 805
# Fetching mass-spectrometry
# queue length 804
# WARNING! metabolomics is already in the list of fetched topics. Skipping.
# Fetching microbiology-techniques
# queue length 802
# Fetching microscopy
# queue length 817
# Fetching molecular-engineering
# queue length 821
# Fetching nanobiotechnology
# queue length 830
# Fetching optogenetics
# queue length 829
# Fetching proteomic-analysis
# queue length 828
# Fetching sensors-and-probes
# queue length 835
# Fetching sequencing
# queue length 841
# Fetching software
# queue length 840
# Fetching spectroscopy
# queue length 846
# Fetching structure-determination
# queue length 851
# Fetching bioenergetics
# queue length 850
# Fetching biological-fluorescence
# queue length 849
# Fetching biopolymers-in-vivo
# queue length 848
# Fetching computational-biophysics
# queue length 847
# Fetching endocytosis
# queue length 846
# Fetching exocytosis
# queue length 845
# Fetching intrinsically-disordered-proteins
# queue length 844
# Fetching membrane-biophysics
# queue length 844
# Fetching membrane-structure-and-assembly
# queue length 843
# Fetching molecular-biophysics
# queue length 848
# Fetching motility
# queue length 854
# Fetching nanoscale-biophysics
# queue length 853
# Fetching permeation-and-transport
# queue length 852
# Fetching single-molecule-biophysics
# queue length 851
# Fetching animal-biotechnology
# queue length 852
# Fetching applied-immunology
# queue length 852
# Fetching assay-systems
# queue length 851
# Fetching biologics
# queue length 869
# Fetching biomaterials
# queue length 878
# Fetching biomimetics
# queue length 878
# Fetching cell-delivery
# queue length 877
# Fetching environmental-biotechnology
# queue length 876
# Fetching expression-systems
# queue length 875
# Fetching functional-genomics
# queue length 878
# WARNING! gene-delivery is already in the list of fetched topics. Skipping.
# Fetching gene-therapy
# queue length 877
# Fetching genomics
# queue length 889
# Fetching industrial-microbiology
# queue length 893
# Fetching metabolic-engineering
# queue length 892
# WARNING! metabolomics is already in the list of fetched topics. Skipping.
# WARNING! molecular-engineering is already in the list of fetched topics. Skipping.
# WARNING! nanobiotechnology is already in the list of fetched topics. Skipping.
# Fetching nucleic-acid-therapeutics
# queue length 894
# Fetching oligo-delivery
# queue length 893
# Fetching peptide-delivery
# queue length 892
# Fetching plant-biotechnology
# queue length 894
# Fetching protein-delivery
# queue length 893
# WARNING! proteomics is already in the list of fetched topics. Skipping.
# Fetching regenerative-medicine
# queue length 891
# WARNING! sequencing is already in the list of fetched topics. Skipping.
# Fetching stem-cell-biotechnology
# queue length 889
# Fetching tissue-engineering
# queue length 888
# Fetching autophagy
# queue length 892
# Fetching cell-adhesion
# queue length 899
# Fetching cell-death
# queue length 902
# Fetching cell-division
# queue length 913
# Fetching cell-growth
# queue length 914
# Fetching cell-migration
# queue length 928
# Fetching cell-polarity
# queue length 929
# Fetching cell-signalling
# queue length 942
# Fetching cellular-imaging
# queue length 942
# Fetching chromosomes
# queue length 944
# Fetching circadian-rhythms
# queue length 943
# Fetching cytoskeleton
# queue length 952
# WARNING! glycobiology is already in the list of fetched topics. Skipping.
# Fetching mechanisms-of-disease
# queue length 950
# Fetching membrane-trafficking
# queue length 969
# Fetching nuclear-organization
# queue length 975
# Fetching nuclear-transport
# queue length 978
# Fetching organelles
# queue length 987
# Fetching post-translational-modifications
# queue length 996
# WARNING! protein-folding is already in the list of fetched topics. Skipping.
# Fetching protein-transport
# queue length 995
# WARNING! proteolysis is already in the list of fetched topics. Skipping.
# Fetching senescence
# queue length 993
# WARNING! biocatalysis is already in the list of fetched topics. Skipping.
# WARNING! biophysical-chemistry is already in the list of fetched topics. Skipping.
# Fetching biosynthesis
# queue length 990
# WARNING! carbohydrates is already in the list of fetched topics. Skipping.
# Fetching chemical-ecology
# queue length 988
# Fetching chemical-genetics
# queue length 987
# Fetching chemical-libraries
# queue length 987
# WARNING! chemical-modification is already in the list of fetched topics. Skipping.
# Fetching chemical-tools
# queue length 985
# Fetching cheminformatics
# queue length 984
# Fetching combinatorial-libraries
# queue length 983
# Fetching computational-chemistry
# queue length 982
# WARNING! dna is already in the list of fetched topics. Skipping.
# Fetching drug-delivery
# queue length 980
# WARNING! enzyme-mechanisms is already in the list of fetched topics. Skipping.
# WARNING! enzymes is already in the list of fetched topics. Skipping.
# WARNING! glycobiology is already in the list of fetched topics. Skipping.
# WARNING! glycomics is already in the list of fetched topics. Skipping.
# WARNING! ion-channels is already in the list of fetched topics. Skipping.
# WARNING! kinases is already in the list of fetched topics. Skipping.
# WARNING! lipidomics is already in the list of fetched topics. Skipping.
# WARNING! lipids is already in the list of fetched topics. Skipping.
# Fetching mechanism-of-action
# queue length 971
# Fetching membranes
# queue length 970
# Fetching metabolic-pathways
# queue length 969
# WARNING! metabolomics is already in the list of fetched topics. Skipping.
# WARNING! metals is already in the list of fetched topics. Skipping.
# Fetching natural-products
# queue length 967
# Fetching networks-and-systems-biology
# queue length 966
# Fetching nucleic-acids
# queue length 965
# WARNING! peptides is already in the list of fetched topics. Skipping.
# Fetching pharmacology
# queue length 968
# WARNING! post-translational-modifications is already in the list of fetched topics. Skipping.
# WARNING! proteases is already in the list of fetched topics. Skipping.
# Fetching protein-design
# queue length 965
# WARNING! protein-folding is already in the list of fetched topics. Skipping.
# WARNING! proteins is already in the list of fetched topics. Skipping.
# WARNING! proteomics is already in the list of fetched topics. Skipping.
# WARNING! rna is already in the list of fetched topics. Skipping.
# Fetching screening
# queue length 960
# Fetching small-molecules
# queue length 959
# Fetching synthetic-biology
# queue length 958
# Fetching target-identification
# queue length 957
# Fetching target-validation
# queue length 956
# Fetching transporters
# queue length 955
# Fetching biochemical-reaction-networks
# queue length 954
# Fetching cellular-signalling-networks
# queue length 953
# Fetching classification-and-taxonomy
# queue length 952
# Fetching communication-and-replication
# queue length 951
# Fetching computational-models
# queue length 950
# Fetching computational-neuroscience
# queue length 955
# Fetching computational-platforms-and-environments
# queue length 954
# Fetching data-acquisition
# queue length 953
# Fetching data-integration
# queue length 952
# Fetching data-mining
# queue length 951
# Fetching data-processing
# queue length 950
# Fetching data-publication-and-archiving
# queue length 949
# Fetching databases
# queue length 950
# Fetching functional-clustering
# queue length 949
# Fetching gene-ontology
# queue length 948
# Fetching gene-regulatory-networks
# queue length 947
# Fetching genome-informatics
# queue length 947
# Fetching hardware-and-infrastructure
# queue length 946
# WARNING! high-throughput-screening is already in the list of fetched topics. Skipping.
# Fetching image-processing
# queue length 944
# Fetching literature-mining
# queue length 943
# Fetching machine-learning
# queue length 942
# Fetching microarrays
# queue length 941
# Fetching network-topology
# queue length 940
# Fetching phylogeny
# queue length 939
# Fetching power-law
# queue length 938
# Fetching predictive-medicine
# queue length 937
# Fetching probabilistic-data-networks
# queue length 936
# Fetching programming-language-and-code
# queue length 935
# Fetching protein-analysis
# queue length 936
# WARNING! protein-design is already in the list of fetched topics. Skipping.
# WARNING! protein-folding is already in the list of fetched topics. Skipping.
# Fetching protein-function-predictions
# queue length 933
# Fetching protein-structure-predictions
# queue length 932
# Fetching proteome-informatics
# queue length 931
# Fetching quality-control
# queue length 930
# Fetching scale-invariance
# queue length 929
# Fetching sequence-annotation
# queue length 928
# WARNING! software is already in the list of fetched topics. Skipping.
# Fetching standards
# queue length 926
# Fetching statistical-methods
# queue length 925
# Fetching virtual-drug-screening
# queue length 924
# Fetching ageing
# queue length 923
# Fetching angiogenesis
# queue length 922
# Fetching bone-development
# queue length 921
# Fetching bone-remodelling
# queue length 922
# Fetching cartilage-development
# queue length 921
# WARNING! cell-growth is already in the list of fetched topics. Skipping.
# Fetching cell-proliferation
# queue length 919
# Fetching ciliogenesis
# queue length 918
# Fetching differentiation
# queue length 917
# Fetching disease-model
# queue length 916
# Fetching embryogenesis
# queue length 920
# Fetching embryology
# queue length 919
# Fetching epigenetic-memory
# queue length 918
# WARNING! experimental-organisms is already in the list of fetched topics. Skipping.
# Fetching germline-development
# queue length 918
# Fetching haematopoiesis
# queue length 922
# Fetching intrauterine-growth
# queue length 921
# Fetching lymphangiogenesis
# queue length 920
# Fetching morphogenesis
# queue length 925
# Fetching neurogenesis
# queue length 926
# Fetching organogenesis
# queue length 930
# Fetching pattern-formation
# queue length 933
# Fetching pluripotency
# queue length 932
# Fetching reprogramming
# queue length 931
# Fetching self-renewal
# queue length 930
# WARNING! senescence is already in the list of fetched topics. Skipping.
# Fetching stem-cell-niche
# queue length 928
# WARNING! stem-cells is already in the list of fetched topics. Skipping.
# Fetching transdifferentiation
# queue length 926
# WARNING! biologics is already in the list of fetched topics. Skipping.
# Fetching biomarkers
# queue length 927
# Fetching business-strategy-in-drug-development
# queue length 934
# Fetching diagnostics
# queue length 933
# WARNING! drug-delivery is already in the list of fetched topics. Skipping.
# Fetching drug-regulation
# queue length 931
# Fetching drug-safety
# queue length 930
# Fetching drug-screening
# queue length 932
# Fetching medicinal-chemistry
# queue length 942
# Fetching pharmaceutics
# queue length 941
# WARNING! pharmacology is already in the list of fetched topics. Skipping.
# WARNING! target-identification is already in the list of fetched topics. Skipping.
# WARNING! target-validation is already in the list of fetched topics. Skipping.
# Fetching toxicology
# queue length 937
# Fetching agri-ecology
# queue length 936
# Fetching animal-migration
# queue length 935
# Fetching behavioural-ecology
# queue length 934
# Fetching biodiversity
# queue length 933
# WARNING! biogeochemistry is already in the list of fetched topics. Skipping.
# Fetching biogeography
# queue length 931
# Fetching biooceanography
# queue length 934
# Fetching boreal-ecology
# queue length 933
# Fetching climate-change-ecology
# queue length 933
# Fetching community-ecology
# queue length 933
# Fetching conservation
# queue length 932
# Fetching ecological-epidemiology
# queue length 931
# Fetching ecological-genetics
# queue length 930
# Fetching ecological-modelling
# queue length 929
# Fetching ecological-networks
# queue length 928
# Fetching ecophysiology
# queue length 927
# Fetching ecosystem-ecology
# queue length 926
# Fetching ecosystem-services
# queue length 925
# Fetching environmental-economics
# queue length 924
# Fetching evolutionary-ecology
# queue length 923
# Fetching fire-ecology
# queue length 922
# Fetching forest-ecology
# queue length 921
# Fetching forestry
# queue length 920
# Fetching freshwater-ecology
# queue length 919
# Fetching grassland-ecology
# queue length 918
# Fetching invasive-species
# queue length 917
# Fetching macroecology
# queue length 916
# Fetching microbial-ecology
# queue length 915
# Fetching molecular-ecology
# queue length 914
# Fetching palaeoecology
# queue length 913
# Fetching population-dynamics
# queue length 912
# Fetching restoration-ecology
# queue length 911
# Fetching riparian-ecology
# queue length 910
# Fetching stable-isotopes
# queue length 909
# Fetching theoretical-ecology
# queue length 908
# Fetching tropical-ecology
# queue length 907
# Fetching urban-ecology
# queue length 906
# Fetching wetlands-ecology
# queue length 905
# Fetching anthropology
# queue length 907
# Fetching archaeology
# queue length 906
# Fetching coevolution
# queue length 905
# Fetching cultural-evolution
# queue length 905
# Fetching evolutionary-developmental-biology
# queue length 904
# Fetching evolutionary-genetics
# queue length 903
# Fetching evolutionary-theory
# queue length 902
# Fetching experimental-evolution
# queue length 901
# Fetching mimicry
# queue length 902
# Fetching molecular-evolution
# queue length 901
# Fetching origin-of-life
# queue length 900
# Fetching palaeontology
# queue length 899
# Fetching phylogenetics
# queue length 898
# Fetching population-genetics
# queue length 898
# Fetching sexual-selection
# queue length 897
# Fetching social-evolution
# queue length 896
# Fetching speciation
# queue length 896
# Fetching taxonomy
# queue length 895
# Fetching agricultural-genetics
# queue length 894
# Fetching animal-breeding
# queue length 893
# Fetching behavioural-genetics
# queue length 892
# Fetching cancer-genetics
# queue length 892
# Fetching cancer-genomics
# queue length 891
# Fetching clinical-genetics
# queue length 896
# Fetching consanguinity
# queue length 895
# Fetching crispr-cas-systems
# queue length 895
# Fetching cytogenetics
# queue length 894
# Fetching development
# queue length 893
# Fetching epigenetics
# queue length 896
# Fetching epigenomics
# queue length 895
# Fetching eukaryote
# queue length 894
# Fetching evolutionary-biology
# queue length 893
# WARNING! functional-genomics is already in the list of fetched topics. Skipping.
# Fetching gene-expression
# queue length 891
# Fetching gene-regulation
# queue length 890
# Fetching genetic-association-study
# queue length 890
# Fetching genetic-hybridization
# queue length 889
# Fetching genetic-interaction
# queue length 889
# Fetching genetic-linkage-study
# queue length 888
# Fetching genetic-markers
# queue length 887
# Fetching genome
# queue length 891
# Fetching genomic-instability
# queue length 891
# WARNING! genomics is already in the list of fetched topics. Skipping.
# Fetching genotype
# queue length 891
# Fetching haplotypes
# queue length 890
# Fetching heritable-quantitative-trait
# queue length 890
# Fetching immunogenetics
# queue length 889
# Fetching inbreeding
# queue length 888
# Fetching medical-genetics
# queue length 888
# Fetching microbial-genetics
# queue length 893
# Fetching mutation
# queue length 895
# Fetching neurodevelopmental-disorders
# queue length 897
# Fetching plant-breeding
# queue length 896
# Fetching plant-genetics
# queue length 899
# Fetching polyploidy
# queue length 899
# WARNING! population-genetics is already in the list of fetched topics. Skipping.
# Fetching prokaryote
# queue length 897
# Fetching quantitative-trait
# queue length 896
# Fetching rna-splicing
# queue length 895
# Fetching rnai
# queue length 894
# WARNING! sequencing is already in the list of fetched topics. Skipping.
# Fetching adaptive-immunity
# queue length 899
# Fetching antigen-processing-and-presentation
# queue length 900
# Fetching antimicrobial-responses
# queue length 899
# WARNING! applied-immunology is already in the list of fetched topics. Skipping.
# Fetching autoimmunity
# queue length 897
# Fetching bone-marrow-transplantation
# queue length 896
# Fetching cell-death-and-immune-response
# queue length 895
# Fetching chemokines
# queue length 894
# Fetching coagulation-system
# queue length 893
# Fetching complement-cascade
# queue length 892
# WARNING! cytokines is already in the list of fetched topics. Skipping.
# Fetching gene-regulation-in-immune-cells
# queue length 893
# WARNING! haematopoiesis is already in the list of fetched topics. Skipping.
# Fetching imaging-the-immune-system
# queue length 891
# Fetching immune-cell-death
# queue length 890
# Fetching immune-evasion
# queue length 889
# WARNING! immunogenetics is already in the list of fetched topics. Skipping.
# Fetching immunological-disorders
# queue length 895
# Fetching immunotherapy
# queue length 896
# Fetching infection
# queue length 895
# Fetching infectious-diseases
# queue length 908
# Fetching inflammation
# queue length 911
# Fetching innate-immune-cells
# queue length 914
# Fetching innate-immunity
# queue length 914
# Fetching lymphatic-system
# queue length 915
# Fetching lymphocytes
# queue length 917
# Fetching lymphoid-tissues
# queue length 921
# Fetching mucosal-immunology
# queue length 920
# Fetching neuroimmunology
# queue length 919
# Fetching osteoimmunology
# queue length 918
# Fetching plant-immunology
# queue length 917
# Fetching signal-transduction
# queue length 917
# Fetching translational-immunology
# queue length 916
# Fetching transplant-immunology
# queue length 917
# Fetching tumour-immunology
# queue length 917
# Fetching vaccines
# queue length 925
# Fetching antimicrobials
# queue length 929
# Fetching applied-microbiology
# queue length 928
# Fetching archaea
# queue length 933
# Fetching bacteria
# queue length 952
# Fetching bacteriology
# queue length 951
# Fetching bacteriophages
# queue length 950
# Fetching biofilms
# queue length 949
# WARNING! biogeochemistry is already in the list of fetched topics. Skipping.
# Fetching cellular-microbiology
# queue length 947
# Fetching clinical-microbiology
# queue length 946
# Fetching communities
# queue length 950
# WARNING! crispr-cas-systems is already in the list of fetched topics. Skipping.
# Fetching environmental-microbiology
# queue length 952
# Fetching fungi
# queue length 961
# WARNING! industrial-microbiology is already in the list of fetched topics. Skipping.
# Fetching infectious-disease-diagnostics
# queue length 959
# WARNING! microbial-genetics is already in the list of fetched topics. Skipping.
# Fetching parasitology
# queue length 965
# Fetching pathogens
# queue length 964
# Fetching phage-biology
# queue length 963
# Fetching policy-and-public-health-in-microbiology
# queue length 962
# WARNING! vaccines is already in the list of fetched topics. Skipping.
# Fetching virology
# queue length 995
# WARNING! cell-division is already in the list of fetched topics. Skipping.
# Fetching chromatin
# queue length 998
# WARNING! chromosomes is already in the list of fetched topics. Skipping.
# WARNING! crispr-cas-systems is already in the list of fetched topics. Skipping.
# Fetching dna-damage-and-repair
# queue length 1006
# Fetching dna-metabolism
# queue length 1005
# Fetching dna-recombination
# queue length 1004
# Fetching dna-replication
# queue length 1010
# WARNING! epigenetics is already in the list of fetched topics. Skipping.
# Fetching non-coding-rnas
# queue length 1013
# WARNING! nuclear-organization is already in the list of fetched topics. Skipping.
# WARNING! post-translational-modifications is already in the list of fetched topics. Skipping.
# WARNING! protein-folding is already in the list of fetched topics. Skipping.
# WARNING! proteolysis is already in the list of fetched topics. Skipping.
# WARNING! proteomics is already in the list of fetched topics. Skipping.
# Fetching riboswitches
# queue length 1007
# Fetching ribozymes
# queue length 1006
# Fetching rna-metabolism
# queue length 1013
# WARNING! rnai is already in the list of fetched topics. Skipping.
# WARNING! single-molecule-biophysics is already in the list of fetched topics. Skipping.
# Fetching transcription
# queue length 1011
# Fetching transcriptomics
# queue length 1010
# Fetching translation
# queue length 1011
# Fetching transposition
# queue length 1010
# Fetching auditory-system
# queue length 1016
# Fetching blood-brain-barrier
# queue length 1015
# Fetching cell-death-in-the-nervous-system
# queue length 1014
# Fetching cellular-neuroscience
# queue length 1013
# Fetching circadian-rhythms-and-sleep
# queue length 1024
# Fetching cognitive-ageing
# queue length 1023
# Fetching cognitive-neuroscience
# queue length 1034
# WARNING! computational-neuroscience is already in the list of fetched topics. Skipping.
# Fetching development-of-the-nervous-system
# queue length 1043
# Fetching diseases-of-the-nervous-system
# queue length 1070
# Fetching emotion
# queue length 1075
# Fetching epigenetics-in-the-nervous-system
# queue length 1076
# Fetching feeding-behaviour
# queue length 1077
# Fetching genetics-of-the-nervous-system
# queue length 1076
# Fetching glial-biology
# queue length 1079
# Fetching gliogenesis
# queue length 1078
# Fetching gustatory-system
# queue length 1079
# Fetching ion-channels-in-the-nervous-system
# queue length 1078
# Fetching learning-and-memory
# queue length 1090
# Fetching molecular-neuroscience
# queue length 1089
# Fetching motivation
# queue length 1088
# Fetching motor-control
# queue length 1096
# Fetching myelin-biology-and-repair
# queue length 1096
# Fetching neural-ageing
# queue length 1095
# Fetching neural-circuit
# queue length 1094
# Fetching neuro-vascular-interactions
# queue length 1093
# WARNING! neurogenesis is already in the list of fetched topics. Skipping.
# WARNING! neuroimmunology is already in the list of fetched topics. Skipping.
# Fetching neuronal-physiology
# queue length 1097
# Fetching neurotrophic-factors
# queue length 1096
# Fetching oculomotor-system
# queue length 1102
# Fetching olfactory-system
# queue length 1104
# Fetching peripheral-nervous-system
# queue length 1105
# Fetching regeneration-and-repair-in-the-nervous-system
# queue length 1105
# Fetching reward
# queue length 1104
# Fetching sensorimotor-processing
# queue length 1108
# Fetching sensory-processing
# queue length 1107
# Fetching sexual-behaviour
# queue length 1110
# Fetching social-behaviour
# queue length 1109
# Fetching social-neuroscience
# queue length 1112
# Fetching somatosensory-system
# queue length 1118
# Fetching spine-regulation-and-structure
# queue length 1120
# Fetching stem-cells-in-the-nervous-system
# queue length 1121
# Fetching stress-and-resilience
# queue length 1120
# Fetching synaptic-plasticity
# queue length 1123
# Fetching synaptic-transmission
# queue length 1127
# Fetching transporters-in-the-nervous-system
# queue length 1126
# Fetching visual-system
# queue length 1133
# WARNING! ageing is already in the list of fetched topics. Skipping.
# Fetching bone
# queue length 1131
# Fetching bone-quality-and-biomechanics
# queue length 1130
# Fetching calcium-and-vitamin-d
# queue length 1129
# Fetching cardiovascular-biology
# queue length 1136
# Fetching circulation
# queue length 1144
# Fetching kidney
# queue length 1144
# Fetching metabolism
# queue length 1151
# Fetching neurophysiology
# queue length 1150
# Fetching reproductive-biology
# queue length 1151
# Fetching respiration
# queue length 1150
# Fetching biofuels
# queue length 1158
# Fetching light-responses
# queue length 1157
# Fetching natural-variation-in-plants
# queue length 1156
# Fetching photosynthesis
# queue length 1162
# WARNING! plant-biotechnology is already in the list of fetched topics. Skipping.
# WARNING! plant-breeding is already in the list of fetched topics. Skipping.
# Fetching plant-cell-biology
# queue length 1169
# Fetching plant-development
# queue length 1178
# Fetching plant-domestication
# queue length 1177
# Fetching plant-ecology
# queue length 1176
# Fetching plant-evolution
# queue length 1175
# WARNING! plant-genetics is already in the list of fetched topics. Skipping.
# Fetching plant-hormones
# queue length 1179
# Fetching plant-immunity
# queue length 1182
# Fetching plant-molecular-biology
# queue length 1181
# Fetching plant-physiology
# queue length 1180
# Fetching plant-reproduction
# queue length 1189
# Fetching plant-signalling
# queue length 1188
# Fetching plant-stress-responses
# queue length 1196
# Fetching plant-symbiosis
# queue length 1198
# Fetching secondary-metabolism
# queue length 1197
# Fetching stomata
# queue length 1196
# Fetching tropism
# queue length 1195
# Fetching human-behaviour
# queue length 1194
# Fetching adult-stem-cells
# queue length 1201
# WARNING! ageing is already in the list of fetched topics. Skipping.
# Fetching cancer-stem-cells
# queue length 1199
# Fetching embryonic-germ-cells
# queue length 1198
# Fetching embryonic-stem-cells
# queue length 1197
# WARNING! epigenetic-memory is already in the list of fetched topics. Skipping.
# Fetching haematopoietic-stem-cells
# queue length 1195
# Fetching heart-stem-cells
# queue length 1194
# Fetching intestinal-stem-cells
# queue length 1193
# Fetching mammary-stem-cells
# queue length 1192
# Fetching mesenchymal-stem-cells
# queue length 1191
# Fetching multipotent-stem-cells
# queue length 1190
# Fetching muscle-stem-cells
# queue length 1189
# Fetching neural-stem-cells
# queue length 1188
# Fetching pluripotent-stem-cells
# queue length 1190
# Fetching quiescence
# queue length 1189
# Fetching regeneration
# queue length 1188
# WARNING! reprogramming is already in the list of fetched topics. Skipping.
# WARNING! self-renewal is already in the list of fetched topics. Skipping.
# Fetching skin-stem-cells
# queue length 1185
# Fetching stem-cell-differentiation
# queue length 1184
# WARNING! stem-cell-niche is already in the list of fetched topics. Skipping.
# Fetching totipotent-stem-cells
# queue length 1182
# WARNING! transdifferentiation is already in the list of fetched topics. Skipping.
# Fetching atomic-force-microscopy
# queue length 1180
# Fetching electron-microscopy
# queue length 1181
# Fetching molecular-modelling
# queue length 1180
# Fetching nmr-spectroscopy
# queue length 1181
# Fetching saxs
# queue length 1180
# Fetching x-ray-crystallography
# queue length 1180
# Fetching bayesian-inference
# queue length 1179
# Fetching biobricks
# queue length 1178
# Fetching biochemical-networks
# queue length 1177
# WARNING! bioenergetics is already in the list of fetched topics. Skipping.
# Fetching cellular-noise
# queue length 1175
# Fetching complexity
# queue length 1174
# Fetching computer-modelling
# queue length 1173
# Fetching computer-science
# queue length 1172
# Fetching control-theory
# queue length 1171
# Fetching criticality
# queue length 1170
# Fetching differential-equations
# queue length 1169
# Fetching dna-computing-and-cryptography
# queue length 1168
# Fetching dynamic-networks
# queue length 1167
# Fetching dynamical-systems
# queue length 1166
# Fetching emergence
# queue length 1165
# Fetching evolvability
# queue length 1164
# Fetching genetic-circuit-engineering
# queue length 1163
# WARNING! genetic-interaction is already in the list of fetched topics. Skipping.
# Fetching genomic-engineering
# queue length 1161
# Fetching information-theory
# queue length 1160
# Fetching logic-gates
# queue length 1159
# WARNING! metabolic-engineering is already in the list of fetched topics. Skipping.
# Fetching modularity
# queue length 1157
# WARNING! molecular-engineering is already in the list of fetched topics. Skipping.
# Fetching molecular-fluctuations
# queue length 1155
# Fetching multicellular-systems
# queue length 1154
# Fetching multistability
# queue length 1153
# Fetching nonlinear-dynamics
# queue length 1152
# Fetching numerical-simulations
# queue length 1151
# Fetching oscillators
# queue length 1150
# WARNING! population-dynamics is already in the list of fetched topics. Skipping.
# WARNING! programming-language-and-code is already in the list of fetched topics. Skipping.
# Fetching protein-engineering
# queue length 1147
# Fetching regulatory-networks
# queue length 1146
# Fetching reverse-engineering
# queue length 1145
# Fetching robustness
# queue length 1144
# Fetching signal-processing
# queue length 1143
# Fetching single-cell-imaging
# queue length 1142
# WARNING! software is already in the list of fetched topics. Skipping.
# Fetching standardization
# queue length 1140
# Fetching stochastic-modelling
# queue length 1139
# Fetching stochastic-networks
# queue length 1138
# WARNING! synthetic-biology is already in the list of fetched topics. Skipping.
# Fetching systems-analysis
# queue length 1136
# Fetching time-series
# queue length 1135
# Fetching animal-behaviour
# queue length 1134
# Fetching animal-physiology
# queue length 1133
# Fetching biomechanics
# queue length 1132
# Fetching entomology
# queue length 1131
# Fetching herpetology
# queue length 1130
# Fetching ichthyology
# queue length 1129
# Fetching carbon-cycle
# queue length 1128
# Fetching element-cycles
# queue length 1127
# Fetching ion-pumps
# queue length 1126
# Fetching ion-transport
# queue length 1125
# Fetching metalloproteins
# queue length 1124
# Fetching amino-sugars
# queue length 1123
# Fetching deoxy-sugars
# queue length 1122
# Fetching dietary-carbohydrates
# queue length 1121
# Fetching glycoconjugates
# queue length 1120
# Fetching glycosides
# queue length 1119
# Fetching monosaccharides
# queue length 1118
# Fetching polysaccharides
# queue length 1117
# Fetching sugar-alcohols
# queue length 1116
# Fetching sugar-phosphates
# queue length 1115
# Fetching autocrine-motility-factor
# queue length 1114
# WARNING! chemokines is already in the list of fetched topics. Skipping.
# Fetching haematopoietic-cell-growth-factors
# queue length 1113
# Fetching hepatocyte-growth-factor
# queue length 1112
# Fetching interferons
# queue length 1111
# Fetching interleukins
# queue length 1110
# Fetching leukaemia-inhibitory-factor
# queue length 1109
# Fetching lymphokines
# queue length 1108
# Fetching monokines
# queue length 1107
# Fetching oncostatin-m
# queue length 1106
# Fetching osteopontin
# queue length 1105
# Fetching transforming-growth-factor-beta
# queue length 1104
# Fetching tumour-necrosis-factors
# queue length 1103
# Fetching catalytic-dna
# queue length 1102
# Fetching catalytic-rna
# queue length 1101
# Fetching dna-repair-enzymes
# queue length 1100
# Fetching dna-restriction-modification-enzymes
# queue length 1099
# Fetching holoenzymes
# queue length 1098
# Fetching hydrolases
# queue length 1097
# Fetching immobilized-enzymes
# queue length 1096
# WARNING! isoenzymes is already in the list of fetched topics. Skipping.
# Fetching isomerases
# queue length 1094
# WARNING! kinases is already in the list of fetched topics. Skipping.
# Fetching ligases
# queue length 1092
# Fetching multienzyme-complexes
# queue length 1091
# Fetching oxidoreductases
# queue length 1090
# Fetching penicillin-binding-proteins
# queue length 1089
# WARNING! proteases is already in the list of fetched topics. Skipping.
# Fetching recombinases
# queue length 1087
# Fetching transferases
# queue length 1086
# Fetching immunohistochemistry
# queue length 1085
# Fetching adrenal-cortex-hormones
# queue length 1084
# Fetching aldosterone
# queue length 1083
# Fetching calcitonin
# queue length 1082
# Fetching ectopic-hormones
# queue length 1081
# Fetching gastrointestinal-hormones
# queue length 1080
# Fetching gonadal-hormones
# queue length 1079
# Fetching insect-hormones
# queue length 1078
# Fetching melatonin
# queue length 1077
# Fetching parathyroid-hormone
# queue length 1076
# Fetching peptide-hormones
# queue length 1075
# Fetching steroid-hormones
# queue length 1074
# Fetching thymus-hormones
# queue length 1073
# Fetching thyroid-hormones
# queue length 1072
# Fetching calcium-channels
# queue length 1071
# Fetching chloride-channels
# queue length 1070
# Fetching cyclic-nucleotide-gated-cation-channels
# queue length 1069
# Fetching ligand-gated-ion-channels
# queue length 1068
# Fetching porins
# queue length 1067
# Fetching potassium-channels
# queue length 1066
# Fetching sodium-channels
# queue length 1065
# Fetching transient-receptor-potential-channels
# queue length 1064
# Fetching ceroid
# queue length 1063
# Fetching fats
# queue length 1062
# Fetching fatty-acids
# queue length 1061
# Fetching fatty-alcohols
# queue length 1060
# Fetching glycerides
# queue length 1059
# Fetching glycolipids
# queue length 1058
# Fetching lipid-peroxides
# queue length 1057
# Fetching lipofuscin
# queue length 1056
# Fetching lipopeptides
# queue length 1055
# Fetching lipopolysaccharides
# queue length 1054
# Fetching lipoproteins
# queue length 1053
# Fetching membrane-lipids
# queue length 1052
# Fetching oils
# queue length 1051
# Fetching phospholipids
# queue length 1050
# Fetching polyhydroxyalkanoates
# queue length 1049
# Fetching sphingolipids
# queue length 1048
# Fetching sterols
# queue length 1047
# Fetching waxes
# queue length 1046
# Fetching calcium
# queue length 1045
# Fetching iron
# queue length 1044
# Fetching magnesium
# queue length 1043
# Fetching potassium
# queue length 1042
# Fetching sodium
# queue length 1041
# Fetching chaperones
# queue length 1040
# Fetching endoplasmic-reticulum
# queue length 1039
# WARNING! prions is already in the list of fetched topics. Skipping.
# Fetching protein-aggregation
# queue length 1037
# Fetching acetyltransferases
# queue length 1036
# Fetching blood-proteins
# queue length 1035
# Fetching carrier-proteins
# queue length 1034
# Fetching cell-cycle-proteins
# queue length 1033
# Fetching cerebrospinal-fluid-proteins
# queue length 1032
# WARNING! chaperones is already in the list of fetched topics. Skipping.
# WARNING! chromatin is already in the list of fetched topics. Skipping.
# Fetching circadian-rhythm-signalling-peptides-and-proteins
# queue length 1029
# Fetching colipases
# queue length 1028
# Fetching complement
# queue length 1027
# Fetching contractile-proteins
# queue length 1026
# Fetching cytoskeletal-proteins
# queue length 1025
# Fetching dna-binding-proteins
# queue length 1024
# Fetching g-protein-coupled-receptors
# queue length 1023
# Fetching glycoproteins
# queue length 1022
# Fetching gtp-binding-protein-regulators
# queue length 1021
# Fetching integrins
# queue length 1020
# Fetching intracellular-signalling-peptides-and-proteins
# queue length 1019
# Fetching lectins
# queue length 1018
# WARNING! lipoproteins is already in the list of fetched topics. Skipping.
# Fetching membrane-proteins
# queue length 1016
# WARNING! metalloproteins is already in the list of fetched topics. Skipping.
# Fetching methylases
# queue length 1014
# Fetching mitochondrial-proteins
# queue length 1013
# Fetching nuclear-receptors
# queue length 1012
# Fetching nucleases
# queue length 1011
# Fetching nucleoproteins
# queue length 1010
# Fetching nucleotide-binding-proteins
# queue length 1009
# Fetching oncogene-proteins
# queue length 1008
# Fetching phosphoproteins
# queue length 1007
# Fetching phosphorylases
# queue length 1006
# Fetching proteome
# queue length 1005
# Fetching ribosomal-proteins
# queue length 1004
# Fetching rna-binding-proteins
# queue length 1003
# Fetching scleroproteins
# queue length 1002
# Fetching selenium-binding-proteins
# queue length 1001
# Fetching sumoylated-proteins
# queue length 1000
# Fetching thioredoxins
# queue length 999
# Fetching transcription-factors
# queue length 998
# Fetching tumour-suppressor-proteins
# queue length 997
# Fetching ubiquitins
# queue length 996
# Fetching ubiquitylated-proteins
# queue length 995
# Fetching viral-proteins
# queue length 994
# Fetching deubiquitylating-enzymes
# queue length 993
# Fetching er-associated-degradation
# queue length 992
# Fetching lysosomes
# queue length 991
# Fetching neddylation
# queue length 990
# Fetching proteasome
# queue length 989
# Fetching protein-quality-control
# queue length 988
# Fetching sumoylation
# queue length 987
# Fetching ubiquitin-ligases
# queue length 986
# Fetching ubiquitylation
# queue length 985
# Fetching protein-protein-interaction-networks
# queue length 984
# Fetching biochemical-assays
# queue length 983
# Fetching gas-chromatography
# queue length 982
# Fetching liquid-chromatography
# queue length 981
# Fetching liquid-liquid-extraction
# queue length 980
# Fetching solid-phase-microextraction
# queue length 979
# Fetching psychophysics
# queue length 978
# Fetching animal-disease-models
# queue length 977
# Fetching cancer-models
# queue length 976
# Fetching cardiovascular-models
# queue length 975
# Fetching gastrointestinal-models
# queue length 974
# Fetching genetic-models
# queue length 973
# Fetching immunological-models
# queue length 972
# Fetching musculoskeletal-models
# queue length 971
# Fetching neurological-models
# queue length 970
# Fetching respiratory-system-models
# queue length 969
# Fetching skin-models
# queue length 968
# Fetching urogenital-models
# queue length 967
# WARNING! atomic-force-microscopy is already in the list of fetched topics. Skipping.
# WARNING! electrophysiology is already in the list of fetched topics. Skipping.
# Fetching magnetic-tweezers
# queue length 964
# Fetching optical-tweezers
# queue length 963
# Fetching cell-culture
# queue length 962
# WARNING! cytogenetics is already in the list of fetched topics. Skipping.
# Fetching flow-cytometry
# queue length 960
# WARNING! high-throughput-screening is already in the list of fetched topics. Skipping.
# Fetching histology
# queue length 958
# Fetching lineage-tracking
# queue length 957
# WARNING! rnai is already in the list of fetched topics. Skipping.
# Fetching tissue-culture
# queue length 955
# Fetching two-hybrid-system
# queue length 954
# Fetching electrocardiography-ekg
# queue length 953
# Fetching electroencephalography-eeg
# queue length 952
# Fetching electromyography-emg
# queue length 951
# Fetching extracellular-recording
# queue length 950
# Fetching intracellular-recording
# queue length 949
# Fetching patch-clamp
# queue length 948
# Fetching single-channel-recording
# queue length 947
# Fetching tetrode-recording
# queue length 946
# Fetching transcranial-magnetic-stimulation
# queue length 945
# Fetching voltage-clamp
# queue length 944
# Fetching chromatin-analysis
# queue length 943
# Fetching histone-analysis
# queue length 942
# Fetching methylation-analysis
# queue length 941
# Fetching model-fungi
# queue length 944
# Fetching model-invertebrates
# queue length 946
# Fetching model-plants
# queue length 952
# Fetching model-prokaryotes
# queue length 955
# Fetching model-protists
# queue length 957
# Fetching model-vertebrates
# queue length 968
# Fetching non-model-organisms
# queue length 967
# Fetching synthetic-organisms
# queue length 966
# Fetching transgenic-organisms
# queue length 965
# Fetching biolistics
# queue length 964
# Fetching genetic-transduction
# queue length 963
# Fetching genetic-vectors
# queue length 962
# Fetching transfection
# queue length 962
# Fetching chromosome-conformation-capture-based-methods
# queue length 961
# Fetching fluorescence-in-situ-hybridization
# queue length 960
# Fetching inhibitory-rna-techniques
# queue length 959
# Fetching microarray-analysis
# queue length 958
# Fetching protein-array-analysis
# queue length 957
# Fetching reporter-genes
# queue length 956
# Fetching reverse-transcription-polymerase-chain-reaction
# queue length 955
# Fetching gene-targeting
# queue length 957
# Fetching genetic-mapping
# queue length 956
# Fetching genotyping-and-haplotyping
# queue length 955
# Fetching pcr-based-techniques
# queue length 954
# Fetching chromatin-immunoprecipitation
# queue length 953
# Fetching comparative-genomic-hybridization
# queue length 952
# Fetching comparative-genomics
# queue length 951
# Fetching gene-expression-profiling
# queue length 950
# Fetching genome-wide-analysis-of-gene-expression
# queue length 949
# Fetching genome-wide-association-studies
# queue length 948
# WARNING! population-genetics is already in the list of fetched topics. Skipping.
# Fetching whole-genome-amplification
# queue length 946
# Fetching bioluminescence-imaging
# queue length 945
# Fetching 3d-reconstruction
# queue length 944
# Fetching diffusion-tensor-imaging
# queue length 943
# Fetching endoscopy
# queue length 946
# Fetching fluorescence-imaging
# queue length 945
# Fetching functional-magnetic-resonance-imaging
# queue length 944
# Fetching magnetic-resonance-imaging
# queue length 943
# Fetching magnetoencephalography
# queue length 942
# Fetching molecular-imaging
# queue length 941
# Fetching optical-imaging
# queue length 940
# Fetching positron-emission-tomography
# queue length 939
# Fetching time-lapse-imaging
# queue length 938
# Fetching ultrasound
# queue length 937
# Fetching viral-tracing
# queue length 936
# Fetching x-ray-tomography
# queue length 935
# Fetching antibody-generation
# queue length 934
# Fetching antibody-isolation-and-purification
# queue length 933
# Fetching elisa
# queue length 932
# Fetching elispot
# queue length 931
# Fetching immunoblotting
# queue length 930
# WARNING! immunohistochemistry is already in the list of fetched topics. Skipping.
# Fetching immunoprecipitation
# queue length 928
# Fetching isolation-of-immune-cells
# queue length 927
# Fetching blotting
# queue length 926
# Fetching chromatography
# queue length 925
# Fetching electrophoresis
# queue length 924
# WARNING! elisa is already in the list of fetched topics. Skipping.
# Fetching protein-enrichment
# queue length 922
# Fetching protein-purification
# queue length 921
# Fetching western-blot
# queue length 920
# WARNING! atomic-force-microscopy is already in the list of fetched topics. Skipping.
# Fetching ca2-imaging
# queue length 918
# Fetching confocal-microscopy
# queue length 917
# Fetching cryoelectron-microscopy
# queue length 916
# Fetching interference-microscopy
# queue length 915
# Fetching light-sheet-microscopy
# queue length 914
# Fetching multiphoton-microscopy
# queue length 913
# Fetching phase-contrast-microscopy
# queue length 912
# Fetching polarization-microscopy
# queue length 911
# Fetching scanning-electron-microscopy
# queue length 910
# Fetching scanning-probe-microscopy
# queue length 909
# Fetching super-resolution-microscopy
# queue length 908
# Fetching total-internal-reflection-microscopy
# queue length 907
# Fetching transmission-electron-microscopy
# queue length 906
# Fetching transmission-light-microscopy
# queue length 905
# Fetching wide-field-fluorescence-microscopy
# queue length 904
# WARNING! antimicrobials is already in the list of fetched topics. Skipping.
# WARNING! metabolic-engineering is already in the list of fetched topics. Skipping.
# WARNING! protein-design is already in the list of fetched topics. Skipping.
# WARNING! synthetic-biology is already in the list of fetched topics. Skipping.
# WARNING! virtual-drug-screening is already in the list of fetched topics. Skipping.
# Fetching applications-of-afm
# queue length 898
# Fetching bionanoelectronics
# queue length 897
# Fetching biosensors
# queue length 896
# Fetching microengraving
# queue length 895
# Fetching microfluidics
# queue length 894
# Fetching nanofabrication-and-nanopatterning
# queue length 893
# Fetching nanoparticles
# queue length 892
# Fetching nanopores
# queue length 891
# Fetching nanostructures
# queue length 890
# Fetching soft-lithography
# queue length 889
# Fetching antisense-elements
# queue length 888
# Fetching dna-probes
# queue length 887
# Fetching fluorescent-dyes
# queue length 886
# Fetching fluorescent-proteins
# queue length 885
# Fetching oligonucleotide-probes
# queue length 884
# Fetching quantum-dots
# queue length 883
# Fetching rna-probes
# queue length 882
# Fetching surface-plasmon-resonance
# queue length 881
# Fetching dna-sequencing
# queue length 880
# Fetching next-generation-sequencing
# queue length 879
# Fetching polysaccharide-sequencing
# queue length 878
# Fetching protein-sequencing
# queue length 877
# Fetching rna-sequencing
# queue length 876
# WARNING! sequence-annotation is already in the list of fetched topics. Skipping.
# Fetching targeted-resequencing
# queue length 874
# Fetching circular-dichroism
# queue length 873
# Fetching fluorescence-resonance-energy-transfer
# queue length 872
# Fetching fluorescence-spectrometry
# queue length 871
# Fetching infrared-spectroscopy
# queue length 870
# Fetching near-infrared-spectroscopy
# queue length 869
# Fetching raman-spectroscopy
# queue length 868
# Fetching spectrophotometry
# queue length 867
# WARNING! atomic-force-microscopy is already in the list of fetched topics. Skipping.
# WARNING! electron-microscopy is already in the list of fetched topics. Skipping.
# WARNING! molecular-modelling is already in the list of fetched topics. Skipping.
# WARNING! nmr-spectroscopy is already in the list of fetched topics. Skipping.
# WARNING! saxs is already in the list of fetched topics. Skipping.
# WARNING! x-ray-crystallography is already in the list of fetched topics. Skipping.
# WARNING! ion-transport is already in the list of fetched topics. Skipping.
# Fetching deformation-dynamics
# queue length 859
# Fetching kinetics
# queue length 858
# Fetching molecular-conformation
# queue length 857
# Fetching perturbations
# queue length 856
# Fetching supramolecular-assembly
# queue length 855
# Fetching thermodynamics
# queue length 854
# Fetching cellular-motility
# queue length 853
# Fetching intracellular-movement
# queue length 852
# Fetching motor-protein-function
# queue length 851
# Fetching motor-protein-regulation
# queue length 850
# Fetching motor-protein-structure
# queue length 849
# Fetching motor-protein-tracks
# queue length 848
# Fetching muscle-contraction
# queue length 847
# Fetching cloning
# queue length 846
# WARNING! genetic-engineering is already in the list of fetched topics. Skipping.
# WARNING! vaccines is already in the list of fetched topics. Skipping.
# Fetching antagomir-and-rna-sponge
# queue length 843
# Fetching antibody-fragment-therapy
# queue length 842
# Fetching antibody-therapy
# queue length 841
# Fetching antisense-oligonucleotide-therapy
# queue length 840
# Fetching cell-therapies
# queue length 840
# Fetching dna-vaccines
# queue length 839
# WARNING! gene-therapy is already in the list of fetched topics. Skipping.
# Fetching locked-nucleic-acid
# queue length 837
# Fetching meganucleases
# queue length 836
# WARNING! nucleic-acid-therapeutics is already in the list of fetched topics. Skipping.
# Fetching peptide-nucleic-acid-oligo
# queue length 834
# Fetching recombinant-peptide-therapy
# queue length 833
# Fetching recombinant-protein-therapy
# queue length 832
# Fetching recombinant-vaccine
# queue length 831
# Fetching rna-vaccines
# queue length 830
# Fetching sirnas
# queue length 829
# Fetching tal-effector-nuclease
# queue length 828
# Fetching triplex-oligo
# queue length 827
# Fetching zinc-finger-nuclease
# queue length 826
# Fetching bioinspired-materials
# queue length 825
# Fetching biomaterials-cells
# queue length 824
# Fetching biomaterials-proteins
# queue length 823
# Fetching biomaterials-vaccines
# queue length 822
# Fetching biomedical-materials
# queue length 821
# Fetching biomineralization
# queue length 820
# Fetching dna-and-rna
# queue length 819
# WARNING! drug-delivery is already in the list of fetched topics. Skipping.
# Fetching implants
# queue length 817
# Fetching tissues
# queue length 816
# Fetching biomimetic-synthesis
# queue length 815
# ...
# WARNING! insula is already in the list of fetched topics. Skipping.
# Fetching pain
# queue length 264
# WARNING! thalamus is already in the list of fetched topics. Skipping.
# Fetching touch-receptors
# queue length 262
# Fetching whisker-system
# queue length 261
# Fetching spine-motility
# queue length 260
# Fetching spine-plasticity
# queue length 259
# Fetching spine-structure
# queue length 258
# Fetching glial-stem-cells
# queue length 257
# WARNING! neural-stem-cells is already in the list of fetched topics. Skipping.
# Fetching long-term-depression
# queue length 255
# Fetching long-term-potentiation
# queue length 254
# Fetching short-term-potentiation
# queue length 253
# Fetching spike-timing-dependent-plasticity
# queue length 252
# Fetching gap-junctions
# queue length 251
# Fetching neurotransmitters
# queue length 250
# Fetching synaptic-vesicle-endocytosis
# queue length 249
# Fetching synaptic-vesicle-exocytosis
# queue length 248
# Fetching vesicle-trafficking
# queue length 247
# Fetching colour-vision
# queue length 246
# Fetching extrastriate-cortex
# queue length 245
# Fetching motion
# queue length 244
# Fetching object-vision
# queue length 243
# Fetching pattern-vision
# queue length 242
# Fetching retina
# queue length 241
# Fetching striate-cortex
# queue length 240
# WARNING! thalamus is already in the list of fetched topics. Skipping.
# WARNING! angiogenesis is already in the list of fetched topics. Skipping.
# Fetching calcification
# queue length 237
# Fetching cardiac-hypertrophy
# queue length 236
# Fetching cardiac-regeneration
# queue length 235
# Fetching cardiovascular-diseases
# queue length 243
# Fetching cardiovascular-genetics
# queue length 242
# Fetching heart-development
# queue length 241
# Fetching platelets
# queue length 240
# Fetching aneurism
# queue length 239
# WARNING! angiogenesis is already in the list of fetched topics. Skipping.
# Fetching atherosclerosis
# queue length 237
# Fetching blood-flow
# queue length 236
# WARNING! calcification is already in the list of fetched topics. Skipping.
# Fetching hypertension
# queue length 236
# WARNING! platelets is already in the list of fetched topics. Skipping.
# Fetching thrombosis
# queue length 234
# Fetching vasodilation
# queue length 233
# Fetching nephrons
# queue length 233
# Fetching fat-metabolism
# queue length 232
# WARNING! feeding-behaviour is already in the list of fetched topics. Skipping.
# Fetching homeostasis
# queue length 230
# Fetching metabolic-diseases
# queue length 235
# WARNING! metabolomics is already in the list of fetched topics. Skipping.
# WARNING! mitochondria is already in the list of fetched topics. Skipping.
# Fetching neuroendocrinology
# queue length 234
# Fetching thyroid-gland
# queue length 233
# Fetching menopause
# queue length 232
# Fetching reproductive-disorders
# queue length 235
# Fetching bioalcohols
# queue length 234
# Fetching biodiesel
# queue length 233
# Fetching bioethers
# queue length 232
# Fetching biogas
# queue length 231
# Fetching biomethanol
# queue length 230
# Fetching crop-waste
# queue length 229
# Fetching green-diesel
# queue length 228
# Fetching solid-biofuels
# queue length 227
# Fetching syngas
# queue length 226
# Fetching antenna-complex
# queue length 225
# Fetching c3-photosynthesis
# queue length 224
# Fetching c4-photosynthesis
# queue length 223
# Fetching non-photochemical-quenching
# queue length 222
# Fetching photosystem-i
# queue length 221
# Fetching photosystem-ii
# queue length 220
# Fetching rubisco
# queue length 219
# Fetching cell-wall
# queue length 218
# WARNING! chloroplasts is already in the list of fetched topics. Skipping.
# Fetching circadian-rhythms-in-plants
# queue length 216
# Fetching plant-cell-cycle
# queue length 215
# Fetching plant-cell-death
# queue length 214
# Fetching plant-cytoskeleton
# queue length 213
# Fetching plant-polarity
# queue length 212
# Fetching plant-transporters
# queue length 211
# Fetching protein-trafficking-in-plants
# queue length 210
# Fetching proteolysis-in-plants
# queue length 209
# Fetching cell-fate
# queue length 208
# Fetching leaf-development
# queue length 207
# Fetching patterning
# queue length 206
# Fetching phyllotaxis
# queue length 205
# Fetching plant-embryogenesis
# queue length 204
# Fetching plant-morphogenesis
# queue length 203
# Fetching plant-regeneration
# queue length 202
# Fetching plant-stem-cell
# queue length 201
# Fetching root-apical-meristem
# queue length 200
# Fetching shoot-apical-meristem
# queue length 199
# Fetching auxin
# queue length 198
# Fetching brassinosteroid
# queue length 197
# Fetching cytokinin
# queue length 196
# Fetching gibberellins
# queue length 195
# Fetching jasmonic-acid
# queue length 194
# Fetching strigolactone
# queue length 193
# Fetching effectors-in-plant-pathology
# queue length 192
# Fetching microbe
# queue length 191
# Fetching pattern-recognition-receptors-in-plants
# queue length 190
# Fetching virulence
# queue length 189
# Fetching fertilization
# queue length 188
# Fetching flowering
# queue length 187
# Fetching fruiting
# queue length 186
# Fetching pollen
# queue length 185
# Fetching pollen-tube
# queue length 184
# Fetching pollination
# queue length 183
# Fetching seed-development
# queue length 182
# Fetching seed-distribution
# queue length 181
# Fetching self-incompatability
# queue length 180
# Fetching vernalization
# queue length 179
# Fetching abiotic
# queue length 178
# Fetching biotic
# queue length 177
# Fetching drought
# queue length 176
# Fetching flooding
# queue length 175
# Fetching heat
# queue length 174
# Fetching herbivory
# queue length 173
# Fetching light-stress
# queue length 172
# Fetching salt
# queue length 171
# Fetching wounding
# queue length 170
# Fetching arbuscular-mycorrhiza
# queue length 169
# Fetching parasitism
# queue length 168
# Fetching rhizobial-symbiosis
# queue length 167
# WARNING! haematopoietic-stem-cells is already in the list of fetched topics. Skipping.
# WARNING! heart-stem-cells is already in the list of fetched topics. Skipping.
# WARNING! intestinal-stem-cells is already in the list of fetched topics. Skipping.
# WARNING! mammary-stem-cells is already in the list of fetched topics. Skipping.
# WARNING! mesenchymal-stem-cells is already in the list of fetched topics. Skipping.
# WARNING! muscle-stem-cells is already in the list of fetched topics. Skipping.
# WARNING! neural-stem-cells is already in the list of fetched topics. Skipping.
# WARNING! skin-stem-cells is already in the list of fetched topics. Skipping.
# WARNING! embryonic-germ-cells is already in the list of fetched topics. Skipping.
# WARNING! embryonic-stem-cells is already in the list of fetched topics. Skipping.
# Fetching induced-pluripotent-stem-cells
# queue length 156
# WARNING! cryoelectron-microscopy is already in the list of fetched topics. Skipping.
# Fetching cryoelectron-tomography
# queue length 154
# Fetching solid-state-nmr
# queue length 153
# Fetching solution-state-nmr
# queue length 152
# Fetching nanocrystallography
# queue length 151
# Fetching erythropoietin
# queue length 150
# Fetching aspergillus-nidulans
# queue length 149
# Fetching neurospora-crassa
# queue length 148
# Fetching saccharomyces-cerevisiae
# queue length 147
# Fetching schizosaccharomyces-pombe
# queue length 146
# Fetching caenorhabditis-elegans
# queue length 145
# Fetching drosophila
# queue length 144
# Fetching sea-anemone
# queue length 143
# Fetching antirrhinum
# queue length 142
# Fetching arabidopsis-thaliana
# queue length 141
# Fetching lotus-japonicus
# queue length 140
# Fetching medicago-truncatula
# queue length 139
# Fetching rice
# queue length 138
# Fetching tobacco
# queue length 137
# Fetching zea-mays
# queue length 136
# Fetching bacillus-subtilis
# queue length 135
# Fetching escherichia-coli
# queue length 134
# Fetching pseudomonas-fluorescens
# queue length 133
# Fetching synechocystis
# queue length 132
# Fetching chlamydomonas-reinhardtii
# queue length 131
# Fetching dictyostelium-discoideum
# queue length 130
# Fetching tetrahymena-thermophila
# queue length 129
# Fetching cat
# queue length 128
# Fetching dog
# queue length 127
# Fetching fugu
# queue length 126
# Fetching guinea-pig
# queue length 125
# Fetching hamster
# queue length 124
# Fetching medaka
# queue length 123
# Fetching mouse
# queue length 122
# Fetching rat
# queue length 121
# Fetching rhesus-macaque
# queue length 120
# Fetching xenopus
# queue length 119
# Fetching zebra-finch
# queue length 118
# Fetching zebrafish
# queue length 117
# Fetching bacterial-transformation
# queue length 116
# WARNING! cas9-endonuclease is already in the list of fetched topics. Skipping.
# WARNING! tal-effector-nuclease is already in the list of fetched topics. Skipping.
# WARNING! zinc-finger-nuclease is already in the list of fetched topics. Skipping.
# Fetching colonoscopy
# queue length 112
# Fetching endomicroscopy
# queue length 111
# Fetching oesophagogastroscopy
# queue length 110
# Fetching video-capsule-endoscopy
# queue length 109
# Fetching stem-cell-therapies
# queue length 108
# Fetching energy-metabolism
# queue length 107
# WARNING! haematopoietic-stem-cells is already in the list of fetched topics. Skipping.
# WARNING! platelets is already in the list of fetched topics. Skipping.
# WARNING! embryonic-induction is already in the list of fetched topics. Skipping.
# Fetching rare-variants
# queue length 103
# Fetching structural-variation
# queue length 102
# Fetching aneuploidy
# queue length 101
# Fetching chimaerism
# queue length 100
# Fetching genetic-translocation
# queue length 99
# Fetching mosaicism
# queue length 98
# Fetching uniparental-disomy
# queue length 97
# WARNING! cancer-epigenetics is already in the list of fetched topics. Skipping.
# WARNING! cancer-genetics is already in the list of fetched topics. Skipping.
# Fetching dna-transposable-elements
# queue length 94
# Fetching antigen-presentation
# queue length 93
# Fetching immunological-memory
# queue length 92
# Fetching immunological-surveillance
# queue length 91
# Fetching lymphocyte-activation
# queue length 90
# Fetching lymphocyte-differentiation
# queue length 89
# Fetching antibodies
# queue length 88
# Fetching germinal-centres
# queue length 87
# WARNING! immunological-memory is already in the list of fetched topics. Skipping.
# Fetching central-tolerance
# queue length 85
# Fetching peripheral-tolerance
# queue length 84
# Fetching mhc-class-i
# queue length 83
# Fetching mhc-class-ii
# queue length 82
# Fetching coeliac-disease
# queue length 81
# WARNING! multiple-sclerosis is already in the list of fetched topics. Skipping.
# Fetching psoriasis
# queue length 79
# Fetching rheumatoid-arthritis
# queue length 78
# Fetching systemic-lupus-erythematosus
# queue length 78
# Fetching type-1-diabetes-mellitus
# queue length 77
# WARNING! hiv-infections is already in the list of fetched topics. Skipping.
# Fetching lymphopaenia
# queue length 75
# Fetching severe-combined-immunodeficiency
# queue length 74
# Fetching allergy
# queue length 73
# Fetching asthma
# queue length 72
# WARNING! atherosclerosis is already in the list of fetched topics. Skipping.
# Fetching atopic-dermatitis
# queue length 70
# Fetching autoinflammatory-syndrome
# queue length 69
# Fetching crohns-disease
# queue length 68
# Fetching inflammatory-bowel-disease
# queue length 70
# WARNING! psoriasis is already in the list of fetched topics. Skipping.
# Fetching ulcerative-colitis
# queue length 68
# Fetching autoimmune-hepatitis
# queue length 67
# Fetching viral-hepatitis
# queue length 68
# Fetching follicular-dendritic-cells
# queue length 67
# Fetching langerhans-cells
# queue length 66
# Fetching myeloid-dendritic-cells
# queue length 65
# Fetching plasmacytoid-dendritic-cells
# queue length 64
# Fetching basophils
# queue length 63
# Fetching eosinophils
# queue length 62
# Fetching mast-cells
# queue length 61
# Fetching neutrophils
# queue length 60
# Fetching alveolar-macrophages
# queue length 59
# Fetching foam-cells
# queue length 58
# Fetching kupffer-cells
# queue length 57
# Fetching microglial-cells
# queue length 56
# Fetching peritoneal-macrophages
# queue length 55
# Fetching phagocytes
# queue length 54
# Fetching nod-like-receptors
# queue length 53
# Fetching rig-i-like-receptors
# queue length 52
# Fetching toll-like-receptors
# queue length 51
# Fetching b-1-cells
# queue length 50
# Fetching b-2-cells
# queue length 49
# Fetching b-cell-receptor
# queue length 48
# Fetching follicular-b-cells
# queue length 47
# Fetching marginal-zone-b-cells
# queue length 46
# Fetching plasma-cells
# queue length 45
# Fetching cd4-positive-t-cells
# queue length 49
# Fetching cd8-positive-t-cells
# queue length 49
# Fetching gammadelta-t-cells
# queue length 48
# Fetching nkt-cells
# queue length 47
# Fetching t-cell-receptor
# queue length 46
# Fetching immunoediting
# queue length 45
# Fetching antibacterial-drug-resistance
# queue length 44
# Fetching bacterial-adhesion
# queue length 43
# WARNING! bacterial-secretion is already in the list of fetched topics. Skipping.
# WARNING! bacterial-transformation is already in the list of fetched topics. Skipping.
# Fetching bacterial-translocation
# queue length 40
# WARNING! alzheimers-disease is already in the list of fetched topics. Skipping.
# Fetching hypoxic-ischaemic-encephalopathy
# queue length 38
# Fetching enteric-nervous-system
# queue length 37
# WARNING! chronic-pain is already in the list of fetched topics. Skipping.
# Fetching acute-coronary-syndromes
# queue length 37
# Fetching arrhythmias
# queue length 39
# Fetching cardiomyopathies
# queue length 39
# Fetching congenital-heart-defects
# queue length 38
# Fetching dyslipidaemias
# queue length 37
# Fetching heart-failure
# queue length 36
# WARNING! hypertension is already in the list of fetched topics. Skipping.
# Fetching valvular-disease
# queue length 34
# Fetching vascular-diseases
# queue length 47
# Fetching pre-eclampsia
# queue length 46
# Fetching renovascular-hypertension
# queue length 45
# Fetching glomerulus
# queue length 45
# Fetching diabetes
# queue length 49
# Fetching metabolic-bone-disease
# queue length 52
# Fetching metabolic-syndrome
# queue length 51
# Fetching multihormonal-system-disorders
# queue length 50
# WARNING! obesity is already in the list of fetched topics. Skipping.
# Fetching pre-diabetes
# queue length 48
# WARNING! hypothalamus is already in the list of fetched topics. Skipping.
# Fetching pituitary-gland
# queue length 46
# Fetching endocrine-reproductive-disorders
# queue length 45
# Fetching infertility
# queue length 44
# Fetching sexual-dysfunction
# queue length 43
# Fetching urogenital-reproductive-disorders
# queue length 42
# Fetching lupus-nephritis
# queue length 41
# Fetching anaemia
# queue length 40
# WARNING! crohns-disease is already in the list of fetched topics. Skipping.
# WARNING! ulcerative-colitis is already in the list of fetched topics. Skipping.
# Fetching hepatitis-b
# queue length 37
# Fetching hepatitis-c
# queue length 36
# Fetching follicular-t-helper-cells
# queue length 35
# Fetching regulatory-t-cells
# queue length 34
# Fetching t-helper-1-cells
# queue length 33
# Fetching t-helper-17-cells
# queue length 32
# Fetching t-helper-2-cells
# queue length 31
# Fetching cytotoxic-t-cells
# queue length 30
# Fetching myocardial-infarction
# queue length 29
# Fetching unstable-angina
# queue length 28
# Fetching atrial-fibrillation
# queue length 27
# Fetching ventricular-fibrillation
# queue length 26
# Fetching ventricular-tachycardia
# queue length 25
# WARNING! cardiac-hypertrophy is already in the list of fetched topics. Skipping.
# WARNING! aneurism is already in the list of fetched topics. Skipping.
# Fetching aortic-diseases
# queue length 22
# Fetching arterial-stiffening
# queue length 21
# WARNING! atherosclerosis is already in the list of fetched topics. Skipping.
# WARNING! calcification is already in the list of fetched topics. Skipping.
# Fetching carotid-artery-disease
# queue length 18
# Fetching cerebrovascular-disorders
# queue length 18
# Fetching coronary-artery-disease-and-stable-angina
# queue length 18
# Fetching embolism
# queue length 17
# Fetching peripheral-vascular-disease
# queue length 16
# Fetching restenosis
# queue length 15
# Fetching thromboembolism
# queue length 14
# WARNING! thrombosis is already in the list of fetched topics. Skipping.
# Fetching vasculitis
# queue length 12
# Fetching podocytes
# queue length 11
# Fetching diabetes-complications
# queue length 10
# Fetching diabetes-insipidus
# queue length 9
# Fetching gestational-diabetes
# queue length 8
# WARNING! type-1-diabetes-mellitus is already in the list of fetched topics. Skipping.
# Fetching type-2-diabetes-mellitus
# queue length 6
# Fetching osteogenesis-imperfecta
# queue length 5
# Fetching osteopetrosis
# queue length 4
# Fetching osteoporosis
# queue length 3
# Fetching pagets-disease
# queue length 2
# WARNING! stroke is already in the list of fetched topics. Skipping.
# Fetching ischaemia
# queue length 0

# %%
def find_parents(subj, tax):
    return [ els['topic_id'] for els in tax if (subj in els['children']) ]

# %%
def max_depth(subj, tax):
    parents = find_parents(subj, tax)
    if len(parents) == 0:
        return 0
    else:
        return 1 + max([ max_depth(parent, tax) for parent in parents ])

# %%
def filter_to_depth(max_depth, tax, depths=None):
    if depths is None:
        depths = {subj['topic_id']: max_depth(subj['topic_id'], tax) for subj in tax}
    valid_topics = [topic_id for (topic_id, depth) in depths.items() if depth<=max_depth]
    return [ subj for subj in tax if subj['topic_id'] in valid_topics ]

# %%
biology_depths = {subj['topic_id']: max_depth(subj['topic_id'], biology_tax) for subj in biology_tax}

# %%
biology_tax_1 = filter_to_depth(1, biology_tax, biology_depths)
biology_tax_2 = filter_to_depth(2, biology_tax, biology_depths)

# %%
print(len(biology_tax_1))
print(len(biology_tax_2))
print(len(biology_tax))
# Out:
# 23
# 449
# 1675

# %%
with open("biological-sciences-full.json", 'w') as file:
    json.dump(biology_tax, file)
with open("biological-sciences-1.json", 'w') as file:
    json.dump(biology_tax_1, file)
with open("biological-sciences-2.json", 'w') as file:
    json.dump(biology_tax_2, file)

# %%
abbrev_list_1 = [{'abbreviation': 'bio_'+subj['topic_id'],
                  'name': subj['name'],
                  'subject': 'bio'}
                  for subj in biology_tax_1 if subj['topic_id'] != 'biological-sciences']

# %%
with open("abbrevs-1.json", 'w') as file:
    json.dump(abbrev_list_1, file)
